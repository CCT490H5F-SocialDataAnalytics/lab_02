# %% [markdown]
# # Lab 02 - Handling Data

# %% [markdown]
# In this lab, we will learn how to manipulate and handle data for analysis in Python. This will lay the foundations for any kind of statistical analysis or data visualizations we would like to build from social data.
#
# Before we begin, you should download this lab like you did with assignment 1 and follow along within the notebook.
#
# ## Data Frames
#
# When we undertake data analysis within social science, we tend to think of datasets which take on a *rectangular* format. Or, in more common terms, in a spreadsheet.
#
# For instance, this is a spreadsheet of MP candidates in the 42nd Canadian national election.
#
# ![](img/data-frame.png)
#
# In typical data analysis, we call the spreadsheet a *data frame*. This is going to be usually be our basic object of analysis for social data.
#
# A data frame consists of *rows* and *columns*. Each row is an observation in the data and our unit of analysis. In the case of the data frame above, each row represents an MP candidate in the election. So for instance, the highlighted row in this data frame is the candidate, Lorraine E. Barnett, who ran as a Conservative candidate in the Avalon district of Newfoundland and Labrador (she lost).
#
# ![](img/data-frame-row.png)
#
# Each column is some attribute, characteristic, or variable about each unit of analysis. For the candidates, this includes their "Political Affiliation", the French name of the party "Appartenance politique", the Candidate's Family and First name, etc.
#
# ![](img/data-frame-column.png)

# %% [markdown]
# ## Data Frames in Python
#
# The main machinery for handling data frames and associated data structures in Python are a set of modules called <code>NumPy</code> and <code>pandas</code>. Usually, these modules are imported using the <code>import</code> function. By convention, these are called <code>np</code> and <code>pd</code>.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# To create data frame in Python, we use the <code>DataFrame</code> *constructor*. A constructor is a special kind of method which creates a new instantiation of a Python object.
#
# The constructor is loaded from the pandas module, so we begin it with a <code>pd</code>.

# %%
# Create an empty dataframe
df = pd.DataFrame()

# %% [markdown]
# This creates an empty DataFrame, which is not of much use to us. We can load data into a data frame in a few ways. We can pass a list of tuples to the constructor. Or we could pass a list of dictionaries.

# %%
df_tuples = pd.DataFrame([(170, 100), (150, 80), (200, 130)])
df_tuples
# Out:
#      0    1
# 0  170  100
# 1  150   80
# 2  200  130

# %%
df_dict = pd.DataFrame([{'Height': 170, 'Weight': 100}, 
                        {'Height': 150, 'Weight': 80}, 
                        {'Height': 200, 'Weight': 130}])
df_dict
# Out:
#    Height  Weight
# 0     170     100
# 1     150      80
# 2     200     130

# %% [markdown]
# Note a few things: typing the name of the data frame in Jupyter Notebook will display the data frame as a table for convenient viewing. If we pass a list of tuples of the <code>DataFrame</code> constructor, they won't have names by default. We do not have to do that when we pass a list of dictionaries.

# %%
# adding columns argument labels the columns
df_tuples = pd.DataFrame([(170, 100), (150, 80), (200, 130)], columns = ['Height', 'Weight'])
df_tuples
# Out:
#    Height  Weight
# 0     170     100
# 1     150      80
# 2     200     130

# %% [markdown]
# Most of the time, however, we won't be passing lists of tuples or dictionaries to create a data frame. We will be loading in the data from a file.

# %% [markdown]
# ## Reading and writing files
#
# The pandas module can load many different kinds of files, including those from Microsoft Excel, and other statistical packages such as Stata or SPSS. The format which we are going to rely on, however, is called Comma-Separated Values, or CSV. CSV files are spreadsheets which are, very simply divided by commas and new lines.
#
# For this lab, we are using [data](http://maps-cartes.ec.gc.ca/indicators-indicateurs/TableView.aspx?ID=1&lang=en) from Environment Canada which measures greenhouse emissions from large facilities. This file is originally in Excel format but I have converted it to CSV to demonstrate the format.
#
# <code>head</code> is a shell program which displays the first few lines of a file. Passing the <code>-2</code> argument means we want to display the first two lines.

# %%
# !head -2 data/Greenhouse_Gas_Emissions.csv
# Out:
# 800,TRT ETGO du Qu�bec,TRT ETGO du Qu�bec inc.,Quebec,B�cancour,555 Alphonse-Deshaies Boulevard,G9H 2Y8,26429,40.03,http://www.ec.gc.ca/ges-ghg/donnees-data/index.cfm?do=facility_info&amp;lang=En&amp;year=2014&amp;ghg_id=G10800,Oilseed Processing,http://www23.statcan.gc.ca/imdb/p3VD.pl?Function=getVDDetail&amp;db=imdb&amp;dis=2&amp;adm=8&amp;TVD=118464&amp;CVD=118471&amp;CST=01012012&amp;MLV=5&amp;CLV=5&amp;CHVD=&amp;CPV=311224,46.38806,-72.37667

# %% [markdown]
# The first line is all the column names. Each of them is separated by a comma. The second line is the first data record. We can see in the Facility Name column, there's a comma in the value itself. Therefore, CSV will put the value in "quotes".
#
# You can load the file using the <code>read_csv</code> method. This method has a lot of different arguments to handle various types of files. You can learn these over time by looking the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html). For now, we will load the file without many options.

# %%
df_gg = pd.read_csv("data/Greenhouse_Gas_Emissions.csv", encoding = "latin1")
df_gg
# Out:
#      Facility ID                              Organisation Name  \
# 0              1                     Produits forestiers Rsolu
# 1              2                    ArcelorMittal Montral Inc.
# 2              3                      Foothills Pipe Lines Ltd.
# 3              4             Kingston CoGen Limited Partnership
# 4              6                                    Agrium Inc.
# 5              7                                    Keyera Corp
# 6              8                         Alliance Pipeline Ltd.
# 7              9         Alberta-Pacific Forest Industries Inc.
# 8             10                                Rio Tinto Alcan
# 9             11                        Essar Steel Algoma Inc.
# 10            12                       Aluminerie Alouette inc.
# 11            13                                  Alcoa Limite
# 12            14                   Aluminerie de Bcancour inc.
# 13            15                    ATCO Gas and Pipelines Ltd.
# 14            18                      Alberta Power (2000) Ltd.
# 15            20                             Bayside Power L.P.
# 16            21                             Graymont (QC) Inc.
# 17            22                New Brunswick Power Corporation
# 18            24                 Saskatchewan Power Corporation
# 19            25                     Produits forestiers Rsolu
# 20            26     City of Winnipeg, Water & Waste Department
# 21            27                                FCA Canada Inc.
# 22            28                                 Manitoba Hydro
# 23            29                              Blaze Energy Ltd.
# 24            30                                    Keyera Corp
# 25            31                      Brighton Beach Power L.P.
# 26            32                                City of Toronto
# 27            33                            Lafarge Canada Inc.
# 28            35                    Glencore Canada Corporation
# 29            36                         Chevron Canada Limited
# ..           ...                                            ...
# 522          759                    Spectra Energy Transmission
# 523          760                     TransCanada PipeLines Ltd.
# 524          762         Waste Management of Canada Corporation
# 525          764              Quicksilver Resources Canada Inc.
# 526          765                        Detour Gold Corporation
# 527          771                      Athabasca Oil Corporation
# 528          772                      Athabasca Oil Corporation
# 529          773                      Athabasca Oil Corporation
# 530          774                         Birchcliff Energy Ltd.
# 531          775             Canadian Natural Resources Limited
# 532          776       ConocoPhillips Canada Energy Partnership
# 533          778                       Devon Canada Corporation
# 534          779                 Enmax Generation Portfolio Inc
# 535          780                   Husky Oil Operations Limited
# 536          781                           Laricina Energy Ltd.
# 537          782                        Les Forges de Sorel Cie
# 538          783                                         MOSAIC
# 539          785                             Nyrstar Myra Falls
# 540          787                       Paramount Resources Ltd.
# 541          788                   Pembina Pipeline Corporation
# 542          789                   Pembina Pipeline Corporation
# 543          790  Peyto Exploration and Development Corporation
# 544          791                                Rio Tinto Alcan
# 545          792                           Shell Canada Limited
# 546          795                            Tourmaline Oil Corp
# 547          796                            Tourmaline Oil Corp
# 548          797                            Tourmaline Oil Corp
# 549          798                            Tourmaline Oil Corp
# 550          799                            Tourmaline Oil Corp
# 551          800                             TRT ETGO du Qubec
#
#                                          Facility Name          Province  \
# 0                                        Division Alma            Quebec
# 1                  Acirie - ArcelorMittal Contrecoeur            Quebec
# 2                          Foothills Pipeline, Alberta           Alberta
# 3                                       Kingston CoGen           Ontario
# 4                       Redwater Fertilizer Operations           Alberta
# 5                                  Alberta Envirofuels           Alberta
# 6          Alliance Pipeline Ltd. - AB Pipeline System           Alberta
# 7               Alberta-Pacific Forest Industries Inc.           Alberta
# 8                                        Kitimat Works  British Columbia
# 9                               Essar Steel Algoma Inc           Ontario
# 10                            Aluminerie Alouette inc.            Quebec
# 11                           Aluminerie de Baie-Comeau            Quebec
# 12                        Aluminerie de Bcancour inc.            Quebec
# 13                                      ATCO Pipelines           Alberta
# 14                     Battle River Generating Station           Alberta
# 15                                       Bayside Power     New Brunswick
# 16                                    Usine de Bedford            Quebec
# 17                        Belledune Generating Station     New Brunswick
# 18                          Boundary Dam Power Station      Saskatchewan
# 19                              Thunder Bay Operations           Ontario
# 20             Brady Road Resource Management Facility          Manitoba
# 21                             Brampton Assembly Plant           Ontario
# 22                          Brandon Generating Station          Manitoba
# 23                                   Brazeau Gas Plant           Alberta
# 24                             Brazeau River Gas Plant           Alberta
# 25                                Brighton Beach Power           Ontario
# 26                                 Brock West Landfill           Ontario
# 27                             Brookfield Cement Plant       Nova Scotia
# 28                                   Brunswick Smelter     New Brunswick
# 29                                    Burnaby Refinery  British Columbia
# ..                                                 ...               ...
# 522              Fort Nelson North Processing Facility  British Columbia
# 523                       TransCanada Pipeline, Quebec            Quebec
# 524   Twin Creeks Landfill (formerly Warwick Landfill)           Ontario
# 525                                  Fortune Creek LFO  British Columbia
# 526                                Detour Lake Project           Ontario
# 527                                  Kaybob East 16-03           Alberta
# 528                                  Kaybob West 07-14           Alberta
# 529                                        Saxon 10-19           Alberta
# 530  Birchcliff Pouce Coupe 03-22-078-12 W6M Gas Plant           Alberta
# 531                            Elk Point South Battery           Alberta
# 532                                  Wembley Gas Plant           Alberta
# 533                              Jackfish 3 SAGD Plant           Alberta
# 534                              Shepard Energy Centre           Alberta
# 535                     Sandall Thermal 06-14-051-24W3      Saskatchewan
# 536                                 Germain SAGD Plant           Alberta
# 537       LES FORGES DE SOREL CIE - ST-JOSEPH-DE-SOREL            Quebec
# 538                             Mosaic Potash Colonsay      Saskatchewan
# 539                             Nyrstar Myra Falls Ltd  British Columbia
# 540              Para 08-13-063-05W6 Musreau Gas Plant           Alberta
# 541        Redwater Fractionation and Storage Facility           Alberta
# 542                     Saturn Deepcut Gas Plant 12-36           Alberta
# 543                      Peyto Swanson 12-31-053-19W5M           Alberta
# 544      Aluminerie Arvida - Centre technologique AP60            Quebec
# 545          Saturn Gas Processing and Production IF-a  British Columbia
# 546                            Banshee 15-12-050-21 W5           Alberta
# 547                             Dawson 13-25-080-16-W6  British Columbia
# 548                       Spirit River 06-03-078-07 W6           Alberta
# 549          Tourmaline Musreau 02/08-13-062-06-W6 Ggs           Alberta
# 550                         Wild River 14-20-056-23 W5           Alberta
# 551                            TRT ETGO du Qubec inc.            Quebec
#
#                                City  \
# 0                              Alma
# 1                       Contrecoeur
# 2                           Airdrie
# 3                              Bath
# 4                   Sturgeon County
# 5                          Edmonton
# 6                           Calgary
# 7               County of Athabasca
# 8                           Kitimat
# 9                  Sault Ste. Marie
# 10                        Sept-ëles
# 11                      Baie-Comeau
# 12                        Bcancour
# 13                         Edmonton
# 14                       Forestburg
# 15                       Saint John
# 16                          Bedford
# 17                        Belledune
# 18                          Estevan
# 19                      Thunder Bay
# 20                         Winnipeg
# 21                         Brampton
# 22                          Brandon
# 23                   Drayton Valley
# 24                   Drayton Valley
# 25                          Windsor
# 26                        Pickering
# 27                       Brookfield
# 28                        Belledune
# 29                          Burnaby
# ..                              ...
# 522                      Cabin Lake
# 523                      Les Cdres
# 524                         Watford
# 525                     Fort Nelson
# 526                        Cochrane
# 527                       Fox Creek
# 528                         Calgary
# 529                         Calgary
# 530                     Pouce Coupe
# 531                      Bonnyville
# 532                         Wembley
# 533                         Conklin
# 534                         Calgary
# 535                   lloydminister
# 536  Municipal District of Opportun
# 537              St-Joseph-de-Sorel
# 538                        Colonsay
# 539                  Campbell River
# 540                       Fox Creek
# 541                        Redwater
# 542                Greenview No. 16
# 543                           Edson
# 544                       Jonquire
# 545                   Fort St. John
# 546               Yellowhead County
# 547                    Dawson Creek
# 548                   Grand Prairie
# 549                    Grande Cache
# 550                          Hinton
# 551                       Bcancour
#
#                                                Address Postal Code  NPRI ID  \
# 0                                 1100 Melanion Street      G8B5W2    983.0
# 1                              3900 Route des Aciries      J0L1C0   3649.0
# 2                                      SW-19-028-26-W4      T4A2G7      NaN
# 3                           5146 Taylor-Kidd Boulevard      K0H1G0   5765.0
# 4                                          56225 SH643      T0A2W0   2134.0
# 5                                     9511 17th Street      T6P1Y3   3974.0
# 6                         800 605 5th Avenue Southwest      T2P3H5      NaN
# 7                                      SW-32-068-19-W4      T0A0M0      1.0
# 8                                   1 Smeltersite Road      V8C2H2   2788.0
# 9                                      105 West Street      P6A7B4   1070.0
# 10                    400 Chemin de de la Pointe-Noire      G4R5M9   4778.0
# 11                                  100 Maritime Route      G4Z2L6   2038.0
# 12                                5555 Pierre Thibault      G9H2T7   1071.0
# 13                            7210 42 Street Northwest      T6B3H1      NaN
# 14                                             Box 498      T0B1N0   1033.0
# 15                                   509 Bayside Drive      E2J1B4   5084.0
# 16                            1015 de la Carriere Road      J0J1A0   5591.0
# 17                                    1558 Main Street      E8G2M3   1698.0
# 18                                     04/05-002-08-W2      S4A2A6   2081.0
# 19                                 2001 Neebing Avenue      P7E6S3    930.0
# 20                                     1901 Brady Road      R3Y1T1   6896.0
# 21                          2000 Williams Parkway East      L6S6B3   4173.0
# 22                           3305 Victoria Avenue East      R7A7J8    821.0
# 23                                     04-31-048-12-W5               3749.0
# 24                                    03-12-046-14-W5M      T7A1S5   1362.0
# 25                                  100 Chappus Street      N9C4J3  11009.0
# 26                                 1390 3rd Concession      L1X2R4      NaN
# 27                                87 Cement Plant Road      B0N1C0   4317.0
# 28                                     692 Main Street     E8G 2M1   4024.0
# 29                         355 Willingdon Avenue North     V5C 1X4   2776.0
# ..                                                 ...         ...      ...
# 522                    Mile 301 Alaska Highway Highway     V0C 1R0  28030.0
# 523                                1370 monte Chnier     J7T 1L8      NaN
# 524                                     8039 Zion Line      N0M2S0  11879.0
# 525                                   a-066-A/094-O-15                  NaN
# 526                                 End of Highway 652              11867.0
# 527                                                ...              26425.0
# 528                                                ...              26426.0
# 529                                     10-19-062-22W5              26427.0
# 530                                   03-22-078-12 W6M                  NaN
# 531                                                ...     T9N 2H4      NaN
# 532                                    06-19-073-08-W6      T0H3S0    536.0
# 533                                     14-24-075-07W4              28033.0
# 534                          9500 100 Street Southeast     T3S 0A2      NaN
# 535                                     06-14-051-24W3                  NaN
# 536                                      3-4-85-22 W4M              27953.0
# 537                                       100 McCarthy      J3R3M8   4797.0
# 538  Highway 2 (approximately 3 miles south of the ...      S0K0Z0   1742.0
# 539                             1 Westmin Road Highway      V1V1V1   2372.0
# 540                                     08-13-063-05W6                  NaN
# 541                                     09-01-056-22W4               5287.0
# 542                                   12-36-057-23 W5M              27964.0
# 543                                     12-31-053-19W5              26264.0
# 544                         2685 Boulevard du Saguenay     G7S 0C9  27853.0
# 545                                   03-28-080-20 W6M              27856.0
# 546                                Mitchell Creek Road              25300.0
# 547                                    13-25-080-16-W6              28043.0
# 548                                    06-03-078-07 W6              19543.0
# 549                                 02/08-13-62-06-W6M              18010.0
# 550                                    14-20-056-23 W5              18844.0
# 551                    555 Alphonse-Deshaies Boulevard     G9H 2Y8  26429.0
#
#      2014 GHG Emissions (kilotonnes of carbon dioxide equivalent)  \
# 0                                                84.38
# 1                                               188.38
# 2                                               232.18
# 3                                               313.36
# 4                                              1172.71
# 5                                               311.44
# 6                                               569.42
# 7                                               124.19
# 8                                               585.48
# 9                                              2757.15
# 10                                             1153.18
# 11                                              499.17
# 12                                              800.92
# 13                                              206.25
# 14                                             4327.63
# 15                                              717.86
# 16                                              486.97
# 17                                             2847.07
# 18                                             4994.43
# 19                                              223.25
# 20                                              381.03
# 21                                               76.80
# 22                                               72.40
# 23                                              150.60
# 24                                              101.23
# 25                                               97.08
# 26                                               17.13
# 27                                              183.20
# 28                                              187.95
# 29                                              490.59
# ..                                                 ...
# 522                                             529.67
# 523                                              53.06
# 524                                              85.50
# 525                                              64.38
# 526                                             141.53
# 527                                              22.70
# 528                                              29.60
# 529                                              16.33
# 530                                              97.57
# 531                                              70.62
# 532                                              52.21
# 533                                             135.37
# 534                                              61.75
# 535                                              96.41
# 536                                              79.84
# 537                                              54.61
# 538                                              54.02
# 539                                              24.59
# 540                                              93.29
# 541                                              63.40
# 542                                              71.42
# 543                                              74.08
# 544                                             103.93
# 545                                              99.15
# 546                                              68.68
# 547                                              51.55
# 548                                              52.99
# 549                                              50.73
# 550                                              76.07
# 551                                              40.03
#
#                                 Facility GHG Data Link  \
# 0    http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 1    http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 2    http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 3    http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 4    http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 5    http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 6    http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 7    http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 8    http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 9    http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 10   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 11   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 12   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 13   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 14   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 15   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 16   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 17   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 18   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 19   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 20   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 21   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 22   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 23   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 24   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 25   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 26   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 27   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 28   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 29   http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# ..                                                 ...
# 522  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 523  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 524  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 525  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 526  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 527  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 528  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 529  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 530  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 531  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 532  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 533  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 534  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 535  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 536  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 537  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 538  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 539  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 540  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 541  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 542  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 543  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 544  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 545  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 546  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 547  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 548  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 549  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 550  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 551  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
#
#                                       NAICS Name  \
# 0                          Mechanical Pulp Mills
# 1          Iron & Steel Mills & Ferro-Alloy Mfg.
# 2         Pipeline Transportation of Natural Gas
# 3          Fossil-Fuel Electric Power Generation
# 4       Chemical Fertilizer (except Potash) Mfg.
# 5              Other Basic Organic Chemical Mfg.
# 6         Pipeline Transportation of Natural Gas
# 7                            Chemical Pulp Mills
# 8       Primary Production of Alumina & Aluminum
# 9          Iron & Steel Mills & Ferro-Alloy Mfg.
# 10      Primary Production of Alumina & Aluminum
# 11      Primary Production of Alumina & Aluminum
# 12      Primary Production of Alumina & Aluminum
# 13        Pipeline Transportation of Natural Gas
# 14         Fossil-Fuel Electric Power Generation
# 15         Fossil-Fuel Electric Power Generation
# 16                                     Lime Mfg.
# 17         Fossil-Fuel Electric Power Generation
# 18         Fossil-Fuel Electric Power Generation
# 19                           Chemical Pulp Mills
# 20                    Waste Treatment & Disposal
# 21    Automobile & Light-Duty Motor Vehicle Mfg.
# 22         Fossil-Fuel Electric Power Generation
# 23             Conventional Oil & Gas Extraction
# 24             Conventional Oil & Gas Extraction
# 25         Fossil-Fuel Electric Power Generation
# 26                    Waste Treatment & Disposal
# 27                                   Cement Mfg.
# 28   Non-Ferrous (except Al) Smelting & Refining
# 29                          Petroleum Refineries
# ..                                           ...
# 522            Conventional Oil & Gas Extraction
# 523       Pipeline Transportation of Natural Gas
# 524                   Waste Treatment & Disposal
# 525            Conventional Oil & Gas Extraction
# 526                     Gold & Silver Ore Mining
# 527            Conventional Oil & Gas Extraction
# 528            Conventional Oil & Gas Extraction
# 529            Conventional Oil & Gas Extraction
# 530            Conventional Oil & Gas Extraction
# 531            Conventional Oil & Gas Extraction
# 532            Conventional Oil & Gas Extraction
# 533              Non-Conventional Oil Extraction
# 534        Fossil-Fuel Electric Power Generation
# 535              Non-Conventional Oil Extraction
# 536              Non-Conventional Oil Extraction
# 537                                      Forging
# 538                                Potash Mining
# 539                       Copper-Zinc Ore Mining
# 540            Conventional Oil & Gas Extraction
# 541            Conventional Oil & Gas Extraction
# 542            Conventional Oil & Gas Extraction
# 543            Conventional Oil & Gas Extraction
# 544     Primary Production of Alumina & Aluminum
# 545            Conventional Oil & Gas Extraction
# 546            Conventional Oil & Gas Extraction
# 547            Conventional Oil & Gas Extraction
# 548            Conventional Oil & Gas Extraction
# 549            Conventional Oil & Gas Extraction
# 550            Conventional Oil & Gas Extraction
# 551                           Oilseed Processing
#
#                                        NAICS Data Link   Latitude   Longitude
# 0    http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  48.563350  -71.656090
# 1    http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  45.820545  -73.263617
# 2    http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...   0.000000    0.000000
# 3    http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  44.209500  -76.724600
# 4    http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  53.841600 -113.097900
# 5    http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  53.531993 -113.364925
# 6    http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...   0.000000    0.000000
# 7    http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  54.923116 -112.861867
# 8    http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  54.010200 -128.703600
# 9    http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  46.520800  -84.369700
# 10   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  50.158300  -66.441600
# 11   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  49.258300  -68.146100
# 12   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  46.382900  -72.387400
# 13   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...   0.000000    0.000000
# 14   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  52.468000 -112.135000
# 15   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  45.275300  -66.026900
# 16   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  45.112300  -73.012900
# 17   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  47.905800  -65.867000
# 18   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  49.042200 -103.032300
# 19   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  48.348600  -89.306700
# 20   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  49.758300  -97.200400
# 21   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  43.751200  -79.716800
# 22   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  49.844900  -99.889600
# 23   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  53.181200 -115.762500
# 24   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  52.947070 -115.902600
# 25   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  42.279800  -83.094600
# 26   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  43.867850  -79.100930
# 27   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  45.239300  -63.334700
# 28   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  47.899200  -65.833900
# 29   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  49.294440 -122.988880
# ..                                                 ...        ...         ...
# 522  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  59.201360 -121.581770
# 523  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...   0.000000    0.000000
# 524  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  42.975700  -81.866900
# 525  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  59.802100 -122.565600
# 526  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  50.017100  -79.703930
# 527  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  54.601600 -116.625730
# 528  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  56.448860 -116.909320
# 529  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  54.379460 -117.285770
# 530  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  55.767600 -119.774700
# 531  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  53.615420 -110.894260
# 532  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  55.335900 -119.223000
# 533  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  55.517040 -110.952330
# 534  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  50.969780 -113.882510
# 535  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  53.400800 -109.436600
# 536  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  56.335400 -113.419900
# 537  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  46.045000  -73.123900
# 538  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  51.933300 -105.763800
# 539  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  49.575000 -125.583000
# 540  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  54.448810 -118.607720
# 541  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  53.812510 -113.127600
# 542  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  53.971920 -117.293430
# 543  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  53.622900 -116.799230
# 544  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  48.431760  -71.159070
# 545  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  55.962000 -121.075000
# 546  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  53.306830 -116.935880
# 547  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  55.957470 -120.373730
# 548  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  55.727700 -119.003200
# 549  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  54.357790 -118.889000
# 550  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  53.857730 -117.384600
# 551  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  46.388060  -72.376670
#
# [552 rows x 14 columns]

# %% [markdown]
# Typing the data frame in Jupyter Notebook will print out the first 30 and the last 30 lines to avoid overloading your output.
#
# Something to note is that the first column of the data frame is not the first column in the file. The first column in the file is <code>Facility ID</code>. But the first column in the data frame is an unlabeled column. This is called the *index*. The index can be defined by us or it can be defined by pandas. If it isn't defined by us, pandas assigns an index which goes from 0 to n-1, where n is the number of rows in the file.

# %% [markdown]
# Once we get a file, we probably want to understand some different parts of it. The key variable in this file is greenhouse gas (GHG) emissions. There's also information on province of the facility, city, address, postal code, and latitude/longitude.
#
# So some basic ways we can learn about the data are to learn about the data frame itself and properties of particular columns.
#
# ## Describing the DataFrame
#
# We can look at the <code>columns</code> list of the data frame to look at which columns are in the data. This is a little prettier than the <code>head</code> command above.

# %%
df_gg.columns
# Out:
# Index(['Facility ID', 'Organisation Name', 'Facility Name', 'Province', 'City',
#        'Address', 'Postal Code', 'NPRI ID',
#        '2014 GHG Emissions (kilotonnes of carbon dioxide equivalent)',
#        'Facility GHG Data Link', 'NAICS Name', 'NAICS Data Link', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %% [markdown]
# We can also look at the <code>shape</code> tuple which tells us how many rows and columns are in the data frame. By convention, this tuple is in the form *(n, m)*, where *n* is the number of rows, and *m* is the number of columns.

# %%
df_gg.shape
# Out:
# (552, 14)

# %% [markdown]
# We can also use <code>dtypes</code> to understand the type of columns in our data.

# %%
df_gg.dtypes
# Out:
# Facility ID                                                       int64
# Organisation Name                                                object
# Facility Name                                                    object
# Province                                                         object
# City                                                             object
# Address                                                          object
# Postal Code                                                      object
# NPRI ID                                                         float64
# 2014 GHG Emissions (kilotonnes of carbon dioxide equivalent)    float64
# Facility GHG Data Link                                           object
# NAICS Name                                                       object
# NAICS Data Link                                                  object
# Latitude                                                        float64
# Longitude                                                       float64
# dtype: object

# %% [markdown]
# Most of the columns are of type <code>object</code>, which typically means they are strings. Facility ID is an int, while four other columns are floats. They have a 64 at the end of them, which means they can be up to 64 bits long. That's not important to know. You should focus on the type instead. Once you know the type, this can help you describe the individual columns.
#
# Lastly, you can use the <code>head()</code> and <code>tail()</code> methods to see the beginning and end of the file. You can pass a number as an optional argument to see several lines. By default, it will display 5.

# %%
df_gg.head(2)
# Out:
#    Facility ID            Organisation Name  \
# 0            1   Produits forestiers Rsolu
# 1            2  ArcelorMittal Montral Inc.
#
#                          Facility Name Province         City  \
# 0                        Division Alma   Quebec         Alma
# 1  Acirie - ArcelorMittal Contrecoeur   Quebec  Contrecoeur
#
#                    Address Postal Code  NPRI ID  \
# 0     1100 Melanion Street      G8B5W2    983.0
# 1  3900 Route des Aciries      J0L1C0   3649.0
#
#    2014 GHG Emissions (kilotonnes of carbon dioxide equivalent)  \
# 0                                              84.38
# 1                                             188.38
#
#                               Facility GHG Data Link  \
# 0  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 1  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
#
#                               NAICS Name  \
# 0                  Mechanical Pulp Mills
# 1  Iron & Steel Mills & Ferro-Alloy Mfg.
#
#                                      NAICS Data Link   Latitude  Longitude
# 0  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  48.563350 -71.656090
# 1  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  45.820545 -73.263617

# %%
df_gg.tail()
# Out:
#      Facility ID    Organisation Name  \
# 547          796  Tourmaline Oil Corp
# 548          797  Tourmaline Oil Corp
# 549          798  Tourmaline Oil Corp
# 550          799  Tourmaline Oil Corp
# 551          800   TRT ETGO du Qubec
#
#                                  Facility Name          Province  \
# 547                     Dawson 13-25-080-16-W6  British Columbia
# 548               Spirit River 06-03-078-07 W6           Alberta
# 549  Tourmaline Musreau 02/08-13-062-06-W6 Ggs           Alberta
# 550                 Wild River 14-20-056-23 W5           Alberta
# 551                    TRT ETGO du Qubec inc.            Quebec
#
#               City                          Address Postal Code  NPRI ID  \
# 547   Dawson Creek                  13-25-080-16-W6              28043.0
# 548  Grand Prairie                  06-03-078-07 W6              19543.0
# 549   Grande Cache               02/08-13-62-06-W6M              18010.0
# 550         Hinton                  14-20-056-23 W5              18844.0
# 551      Bcancour  555 Alphonse-Deshaies Boulevard     G9H 2Y8  26429.0
#
#      2014 GHG Emissions (kilotonnes of carbon dioxide equivalent)  \
# 547                                              51.55
# 548                                              52.99
# 549                                              50.73
# 550                                              76.07
# 551                                              40.03
#
#                                 Facility GHG Data Link  \
# 547  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 548  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 549  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 550  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 551  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
#
#                             NAICS Name  \
# 547  Conventional Oil & Gas Extraction
# 548  Conventional Oil & Gas Extraction
# 549  Conventional Oil & Gas Extraction
# 550  Conventional Oil & Gas Extraction
# 551                 Oilseed Processing
#
#                                        NAICS Data Link  Latitude  Longitude
# 547  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  55.95747 -120.37373
# 548  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  55.72770 -119.00320
# 549  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  54.35779 -118.88900
# 550  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  53.85773 -117.38460
# 551  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  46.38806  -72.37667

# %% [markdown]
# ## Describing columns
#
# We generally want to try to detect some patterns in the data, and for that we need to analyze some properties of the columns. Since GHG emissions is the main variable, we can do some basic statistical operations on that variable. We can get measures of central tendency, such as mean and median, and measures of dispersion, such as standard deviation and range.
#
# We can access particular columns by typing the name of the data frame and putting the column name in quotes.

# %%
## measures of central tendency
df_gg['2014 GHG Emissions (kilotonnes of carbon dioxide equivalent)'].mean()
# Out:
# 469.49829710144934

# %%
df_gg['2014 GHG Emissions (kilotonnes of carbon dioxide equivalent)'].median()
# Out:
# 117.305

# %%
## measures of dispersion
df_gg['2014 GHG Emissions (kilotonnes of carbon dioxide equivalent)'].std()
# Out:
# 1251.7750797697197

# %%
df_gg['2014 GHG Emissions (kilotonnes of carbon dioxide equivalent)'].min()
# Out:
# 0.0

# %%
df_gg['2014 GHG Emissions (kilotonnes of carbon dioxide equivalent)'].max()
# Out:
# 15096.040000000001

# %% [markdown]
# Often we are dealing with non-numerical data. Most of the columns in this data frame are in fact non-numeric (in statistics we would call them *categorical* or *ordinal* variables). These contain important information about the facility.
#
# Say we want to know which province is most represented here. We can use the <code>value_counts()</code> method on the *Province* column to learn this.

# %%
df_gg['Province'].value_counts()
# Out:
# Alberta                      171
# Ontario                      139
# Quebec                        84
# British Columbia              72
# Saskatchewan                  39
# New Brunswick                 12
# Manitoba                      12
# Nova Scotia                    9
# Newfoundland and Labrador      8
# Northwest Territories          4
# Prince Edward Island           1
# Nunavut                        1
# Name: Province, dtype: int64

# %% [markdown]
# Alberta has the highest proportion of facilities with a large amount of GHG emissions. Which seems to make sense, since Alberta processes a great deal of fossil fuels.
#
# If we just want to know which provinces are in the dataset, we could use the <code>unique()</code> method.

# %%
df_gg['Province'].unique()
# Out:
# array(['Quebec', 'Alberta', 'Ontario', 'British Columbia', 'New Brunswick',
#        'Saskatchewan', 'Manitoba', 'Nova Scotia',
#        'Newfoundland and Labrador', 'Prince Edward Island',
#        'Northwest Territories', 'Nunavut'], dtype=object)

# %% [markdown]
# ## Exercise 1
#
# The [iris dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set) measures several properties of different iris flowers of  different species. We can use it here because it is an easy way to demonstrate pandas operations. For this exercise, do the following:
#
# 1. Load the iris dataset. It is located at 'data/iris.csv'.
# 2. Print the data frame. Display its dimensions and its types.
# 3. Take the mean and median of sepal length.
# 4. Get the min and max of petal width.
# 5. Count how many times each species occurs in the dataset.

# %% [markdown]
# ## Adding and removing columns
#
# Once we have the data frame, we can change it in important ways. We can add new columns to store new information or we can rename columns.
#
# The GHG emissions column has a really long name. Let's just call it GHG

# %%
df_gg['GHG'] = df_gg['2014 GHG Emissions (kilotonnes of carbon dioxide equivalent)']
del df_gg['2014 GHG Emissions (kilotonnes of carbon dioxide equivalent)']

# %% [markdown]
# This does two things. It assigns the values in the original column to a new one. Then, it deletes the original column with the <code>del</code> operator. This will also change the order of the columns because pandas will add GHG to the end. You can confirm this by yourself by typing <code>df_gg.columns</code> again.
#
# You can set new entire columns by assigning a value to them. Let's say we want to add a country column. These are all in Canada, so we can just set them to Canada.

# %%
df_gg['Country'] = 'Canada'

# %% [markdown]
# This isn't terribly useful here, but once we show how to take slices of data, it is much more powerful.

# %% [markdown]
# ## Slicing and indexing
#
# One of the big reasons that pandas was created is because Python needed a way to index and access data by names and to use those indexes to perform multiple operations at once. This is where slicing and indexing comes in. This is both the most powerful (and often most frustrating) parts of pandas.
#
# For instance, say I just want to look at GHG emissions within Ontario. I can subset the data by using a conditional statement that matches for instances of Ontario in the province variable. I can also assign that to a new data frame.

# %%
df_gg_ON = df_gg[df_gg['Province'] == 'Ontario']
df_gg_ON.shape
# Out:
# (139, 15)

# %%
df_gg_ON.head(3)
# Out:
#     Facility ID                   Organisation Name           Facility Name  \
# 3             4  Kingston CoGen Limited Partnership          Kingston CoGen
# 9            11             Essar Steel Algoma Inc.  Essar Steel Algoma Inc
# 19           25          Produits forestiers Rsolu  Thunder Bay Operations
#
#    Province              City                     Address Postal Code  \
# 3   Ontario              Bath  5146 Taylor-Kidd Boulevard      K0H1G0
# 9   Ontario  Sault Ste. Marie             105 West Street      P6A7B4
# 19  Ontario       Thunder Bay         2001 Neebing Avenue      P7E6S3
#
#     NPRI ID                             Facility GHG Data Link  \
# 3    5765.0  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 9    1070.0  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 19    930.0  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
#
#                                NAICS Name  \
# 3   Fossil-Fuel Electric Power Generation
# 9   Iron & Steel Mills & Ferro-Alloy Mfg.
# 19                    Chemical Pulp Mills
#
#                                       NAICS Data Link  Latitude  Longitude  \
# 3   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...   44.2095   -76.7246
# 9   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...   46.5208   -84.3697
# 19  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...   48.3486   -89.3067
#
#         GHG Country
# 3    313.36  Canada
# 9   2757.15  Canada
# 19   223.25  Canada

# %% [markdown]
# We can also index by numerical conditions. Let's get all the facilities which have GHG emissions higher than the median.

# %%
df_gg_top50percent = df_gg[df_gg['GHG'] > df_gg['GHG'].median()]
df_gg_top50percent.shape
# Out:
# (276, 15)

# %%
df_gg_top50percent.head(3)
# Out:
#    Facility ID                   Organisation Name  \
# 1            2         ArcelorMittal Montral Inc.
# 2            3           Foothills Pipe Lines Ltd.
# 3            4  Kingston CoGen Limited Partnership
#
#                          Facility Name Province         City  \
# 1  Acirie - ArcelorMittal Contrecoeur   Quebec  Contrecoeur
# 2          Foothills Pipeline, Alberta  Alberta      Airdrie
# 3                       Kingston CoGen  Ontario         Bath
#
#                       Address Postal Code  NPRI ID  \
# 1     3900 Route des Aciries      J0L1C0   3649.0
# 2             SW-19-028-26-W4      T4A2G7      NaN
# 3  5146 Taylor-Kidd Boulevard      K0H1G0   5765.0
#
#                               Facility GHG Data Link  \
# 1  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 2  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 3  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
#
#                                NAICS Name  \
# 1   Iron & Steel Mills & Ferro-Alloy Mfg.
# 2  Pipeline Transportation of Natural Gas
# 3   Fossil-Fuel Electric Power Generation
#
#                                      NAICS Data Link   Latitude  Longitude  \
# 1  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  45.820545 -73.263617
# 2  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...   0.000000   0.000000
# 3  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  44.209500 -76.724600
#
#       GHG Country
# 1  188.38  Canada
# 2  232.18  Canada
# 3  313.36  Canada

# %% [markdown]
# Finally, we can combine different conditions with logical operators <code>&</code> and <code>|</code>. <code>&</code> (called an ampersand) is an operator referred to as "bitwise and", while <code>|</code> (called a pipe) is an operator referred to as "bitwise or".
#
# We also need to wrap each condition in parenthesis.
#
# Let's get those which are in the top 50 percent and also are in Ontario.

# %%
df_gg_top50percent_ON = df_gg[(df_gg['GHG'] > df_gg['GHG'].median()) & (df_gg['Province'] == 'Ontario')]
df_gg_top50percent_ON.shape
# Out:
# (67, 15)

# %%
df_gg_top50percent_ON.head(3)
# Out:
#     Facility ID                   Organisation Name           Facility Name  \
# 3             4  Kingston CoGen Limited Partnership          Kingston CoGen
# 9            11             Essar Steel Algoma Inc.  Essar Steel Algoma Inc
# 19           25          Produits forestiers Rsolu  Thunder Bay Operations
#
#    Province              City                     Address Postal Code  \
# 3   Ontario              Bath  5146 Taylor-Kidd Boulevard      K0H1G0
# 9   Ontario  Sault Ste. Marie             105 West Street      P6A7B4
# 19  Ontario       Thunder Bay         2001 Neebing Avenue      P7E6S3
#
#     NPRI ID                             Facility GHG Data Link  \
# 3    5765.0  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 9    1070.0  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 19    930.0  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
#
#                                NAICS Name  \
# 3   Fossil-Fuel Electric Power Generation
# 9   Iron & Steel Mills & Ferro-Alloy Mfg.
# 19                    Chemical Pulp Mills
#
#                                       NAICS Data Link  Latitude  Longitude  \
# 3   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...   44.2095   -76.7246
# 9   http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...   46.5208   -84.3697
# 19  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...   48.3486   -89.3067
#
#         GHG Country
# 3    313.36  Canada
# 9   2757.15  Canada
# 19   223.25  Canada

# %% [markdown]
# This is probably the most important way you're going to be splitting data within pandas. You can also get different data by position in the table. Let's say I just want to get the first two rows of the file. We can use a syntax which is the same as list slices.

# %%
df_gg[0:2]
# Out:
#    Facility ID            Organisation Name  \
# 0            1   Produits forestiers Rsolu
# 1            2  ArcelorMittal Montral Inc.
#
#                          Facility Name Province         City  \
# 0                        Division Alma   Quebec         Alma
# 1  Acirie - ArcelorMittal Contrecoeur   Quebec  Contrecoeur
#
#                    Address Postal Code  NPRI ID  \
# 0     1100 Melanion Street      G8B5W2    983.0
# 1  3900 Route des Aciries      J0L1C0   3649.0
#
#                               Facility GHG Data Link  \
# 0  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 1  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
#
#                               NAICS Name  \
# 0                  Mechanical Pulp Mills
# 1  Iron & Steel Mills & Ferro-Alloy Mfg.
#
#                                      NAICS Data Link   Latitude  Longitude  \
# 0  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  48.563350 -71.656090
# 1  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  45.820545 -73.263617
#
#       GHG Country
# 0   84.38  Canada
# 1  188.38  Canada

# %% [markdown]
# In a similar manner, we can also select on several columns. Say we only want to know the facility name, the province, its city, and its GHG value. We can index the data frame by a list of column names.

# %%
df_gg[['Facility Name', 'City', 'Province', 'GHG']].head()
# Out:
#                          Facility Name             City Province      GHG
# 0                        Division Alma             Alma   Quebec    84.38
# 1  Acirie - ArcelorMittal Contrecoeur      Contrecoeur   Quebec   188.38
# 2          Foothills Pipeline, Alberta          Airdrie  Alberta   232.18
# 3                       Kingston CoGen             Bath  Ontario   313.36
# 4       Redwater Fertilizer Operations  Sturgeon County  Alberta  1172.71

# %% [markdown]
# ## Manipulating data
#
# Another nifty thing about pandas is that we can manipulate data across columns, rows, and even multiple columns and rows, at the same time.
#
# Say we want to convert the GHG variable from kilotonnes to just tonnes. That would mean we multiple the column by 1000.

# %%
df_gg['GHG_tonnes'] = df_gg['GHG'] * 1000
df_gg[['GHG', 'GHG_tonnes']].head()
# Out:
#        GHG  GHG_tonnes
# 0    84.38     84380.0
# 1   188.38    188380.0
# 2   232.18    232180.0
# 3   313.36    313360.0
# 4  1172.71   1172710.0

# %% [markdown]
# We can use the GHG variable (and any numeric variable) in most kinds of arithmetic operations we could like.
#
# For string columns, there's a set of methods we can use with those columns. Many of them are similar to the ones we saw last week. The full list is [here](http://pandas.pydata.org/pandas-docs/stable/text.html).
#
# Let's say that Toronto officially its name to "DrakeLand" tomorrow. We can use <code>contains</code> as an index to find all instances where the City column matches Toronto. **Notice** how after accessing the City column, we use <code>str</code> to note that this is a string operation.

# %%
df_gg[df_gg['City'].str.contains('Toronto')].head()
# Out:
#      Facility ID           Organisation Name              Facility Name  \
# 322          413  Portlands Energy Centre LP    Portlands Energy Centre
# 347          459   Enwave Energy Corporation   Pearl Street Steam Plant
# 348          460   Enwave Energy Corporation  Walton Street Steam Plant
# 362          481    Irving Consumer Products              Irving Tissue
# 384          537           Redpath Sugar Ltd           Toronto Refinery
#
#     Province     City               Address Postal Code  NPRI ID  \
# 322  Ontario  Toronto      470 Unwin Avenue      M4M3B9  11803.0
# 347  Ontario  Toronto      120 Pearl Street      M5H1L2   7656.0
# 348  Ontario  Toronto      95 Walton Street      M5G1H9   7657.0
# 362  Ontario  Toronto      1551 Weston Road      M6M4Y4    327.0
# 384  Ontario  Toronto  95 Queen's Quay East      M5E1A3   2016.0
#
#                                 Facility GHG Data Link  \
# 322  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 347  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 348  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 362  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 384  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
#
#                                 NAICS Name  \
# 322  Fossil-Fuel Electric Power Generation
# 347        Steam & Air-Conditioning Supply
# 348        Steam & Air-Conditioning Supply
# 362         Paper (except Newsprint) Mills
# 384                             Sugar Mfg.
#
#                                        NAICS Data Link  Latitude  Longitude  \
# 322  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  43.64950  -79.33110
# 347  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  43.64828  -79.38596
# 348  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  43.65795  -79.38527
# 362  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  43.69415  -79.50455
# 384  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  43.38500  -79.22300
#
#         GHG Country  GHG_tonnes
# 322  371.37  Canada    371370.0
# 347  109.37  Canada    109370.0
# 348   98.58  Canada     98580.0
# 362   59.64  Canada     59640.0
# 384   60.06  Canada     60060.0

# %% [markdown]
# Now, we can replace all instances of "Toronto" with "DrakeLand".

# %%
df_gg['City'] = df_gg['City'].str.replace('Toronto', 'DrakeLand')

# %%
## This should not display any rows.
df_gg[df_gg['City'].str.contains('Toronto')].head()
# Out:
# Empty DataFrame
# Columns: [Facility ID, Organisation Name, Facility Name, Province, City, Address, Postal Code, NPRI ID, Facility GHG Data Link, NAICS Name, NAICS Data Link, Latitude, Longitude, GHG, Country, GHG_tonnes]
# Index: []

# %%
## Best I Ever Had
df_gg[df_gg['City'].str.contains('DrakeLand')].head()
# Out:
#      Facility ID           Organisation Name              Facility Name  \
# 322          413  Portlands Energy Centre LP    Portlands Energy Centre
# 347          459   Enwave Energy Corporation   Pearl Street Steam Plant
# 348          460   Enwave Energy Corporation  Walton Street Steam Plant
# 362          481    Irving Consumer Products              Irving Tissue
# 384          537           Redpath Sugar Ltd           Toronto Refinery
#
#     Province       City               Address Postal Code  NPRI ID  \
# 322  Ontario  DrakeLand      470 Unwin Avenue      M4M3B9  11803.0
# 347  Ontario  DrakeLand      120 Pearl Street      M5H1L2   7656.0
# 348  Ontario  DrakeLand      95 Walton Street      M5G1H9   7657.0
# 362  Ontario  DrakeLand      1551 Weston Road      M6M4Y4    327.0
# 384  Ontario  DrakeLand  95 Queen's Quay East      M5E1A3   2016.0
#
#                                 Facility GHG Data Link  \
# 322  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 347  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 348  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 362  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
# 384  http://www.ec.gc.ca/ges-ghg/donnees-data/index...
#
#                                 NAICS Name  \
# 322  Fossil-Fuel Electric Power Generation
# 347        Steam & Air-Conditioning Supply
# 348        Steam & Air-Conditioning Supply
# 362         Paper (except Newsprint) Mills
# 384                             Sugar Mfg.
#
#                                        NAICS Data Link  Latitude  Longitude  \
# 322  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  43.64950  -79.33110
# 347  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  43.64828  -79.38596
# 348  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  43.65795  -79.38527
# 362  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  43.69415  -79.50455
# 384  http://www23.statcan.gc.ca/imdb/p3VD.pl?Functi...  43.38500  -79.22300
#
#         GHG Country  GHG_tonnes
# 322  371.37  Canada    371370.0
# 347  109.37  Canada    109370.0
# 348   98.58  Canada     98580.0
# 362   59.64  Canada     59640.0
# 384   60.06  Canada     60060.0

# %% [markdown]
# We can also do things like capitalize or lowercase strings. Let's do the province names.

# %%
df_gg['Province'] = df_gg['Province'].str.lower()
df_gg['Province'].unique()
# Out:
# array(['quebec', 'alberta', 'ontario', 'british columbia', 'new brunswick',
#        'saskatchewan', 'manitoba', 'nova scotia',
#        'newfoundland and labrador', 'prince edward island',
#        'northwest territories', 'nunavut'], dtype=object)

# %%
## Let's convert them back
df_gg['Province'] = df_gg['Province'].str.capitalize()
df_gg['Province'].unique()
# Out:
# array(['Quebec', 'Alberta', 'Ontario', 'British columbia', 'New brunswick',
#        'Saskatchewan', 'Manitoba', 'Nova scotia',
#        'Newfoundland and labrador', 'Prince edward island',
#        'Northwest territories', 'Nunavut'], dtype=object)

# %%
## We can use title to capitalize the beginning of each word
df_gg['Province'] = df_gg['Province'].str.title()
df_gg['Province'].unique()
# Out:
# array(['Quebec', 'Alberta', 'Ontario', 'British Columbia', 'New Brunswick',
#        'Saskatchewan', 'Manitoba', 'Nova Scotia',
#        'Newfoundland And Labrador', 'Prince Edward Island',
#        'Northwest Territories', 'Nunavut'], dtype=object)

# %% [markdown]
# ## Exercise 2
#
# 1. Go back to the Iris dataset. Select only the rows which have a sepal length larger than the mean. Assign them to a new dataframe.
# 2. Select flowers which 1) have a sepal width larger than the mean and 2) belong to the species setosa. Assign them to a new dataframe.
# 3. Create a new data frame which only has two columns: petal length and petal width.
# 4. Convert all numeric values to meters from centimeters.
# 5. Change the name of all flowers with the species virginica to "harmonica".
